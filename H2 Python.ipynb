# %%
import pandas

# %%
lostsuper = pandas.read_csv('H2_Data_Table.csv')
lostsuper
# Out:
#       Postcode Suburb State  LS_Accounts   LS_Value  Population  \
# 0         1000    NaN   NaN            4   39096.72         NaN
# 1         1001    NaN   NaN            3  111534.99         NaN
# 2         1010    NaN   NaN            1    6029.73         NaN
# 3         1021    NaN   NaN            1   12479.15         NaN
# 4         1041    NaN   NaN            2   13132.80         NaN
# 5         1043    NaN   NaN            1    7583.22         NaN
# 6         1050    NaN   NaN            1    9507.06         NaN
# 7         1072    NaN   NaN            1    5064.12         NaN
# 8         1100    NaN   NaN            1   11632.28         NaN
# 9         1111    NaN   NaN           34  305112.41         NaN
# 10        1121    NaN   NaN            1   11135.98         NaN
# 11        1176    NaN   NaN            1    4203.56         NaN
# 12        1181    NaN   NaN            1    5131.17         NaN
# 13        1195    NaN   NaN            1    7362.14         NaN
# ...

# %%
lostsuper.LS_Value.value_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ae9293b475a5> in <module>()
# ----> 1 lostsuper.LS_Value.value_count
#
# /Users/chrislumby/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
lostsuper.dtypes
# Out:
# Postcode                    int64
# Suburb                     object
# State                      object
# LS_Accounts                 int64
# LS_Value                  float64
# Population                float64
# LS_Accounts_Per_Person    float64
# LS_Value_Per_Person       float64
# Tax_Population            float64
# Tax_Median_Income         float64
# Tax_Mean_Income           float64
# dtype: object

# %%
lostsuper.LS_Value.describe()
# Out:
# count    3.045000e+03
# mean     3.544305e+06
# std      5.521221e+06
# min      3.051000e+01
# 25%      1.413125e+05
# 50%      8.657510e+05
# 75%      4.935973e+06
# max      4.925634e+07
# Name: LS_Value, dtype: float64

# %%
lostsuper.Suburb.unique()
# Out:
# array([nan, 'Barangaroo', 'Camperdown (NSW)', ..., 'Halls Creek (WA)',
#        'Christmas Island', 'Directions Island'], dtype=object)

# %%
lostsuper.describe()
# Out:
#           Postcode  LS_Accounts      LS_Value    Population  \
# count  3045.000000  3045.000000  3.045000e+03    2492.00000
# mean   4151.841051   181.625287  3.544305e+06    8608.33427
# std    1690.498126   285.385876  5.521221e+06   11468.34475
# min     200.000000     1.000000  3.051000e+01       0.00000
# 25%    2779.000000     8.000000  1.413125e+05     877.75000
# 50%    3921.000000    46.000000  8.657510e+05    3627.00000
# 75%    5352.000000   252.000000  4.935973e+06   12733.25000
# max    9799.000000  2903.000000  4.925634e+07  102245.00000
#
#        LS_Accounts_Per_Person  LS_Value_Per_Person  Tax_Population  \
# count             2489.000000          2489.000000     2202.000000
# mean                 0.028534           537.938887     5790.429155
# std                  0.071572          1355.703831     7037.288168
# min                  0.000000             0.120000      201.000000
# 25%                  0.020000           322.130000      777.000000
# ...

# %%
lostsuper.Population.describe()
# Out:
# count      2492.00000
# mean       8608.33427
# std       11468.34475
# min           0.00000
# 25%         877.75000
# 50%        3627.00000
# 75%       12733.25000
# max      102245.00000
# Name: Population, dtype: float64

# %% [markdown]
# next lines areremoving the nulls where there is a postcode with lost super attached but the postcode is not real

# %%
lostsuper.Population.isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 3015    True
# 3016    True
# 3017    True
# 3018    True
# 3019    True
# 3020    True
# 3021    True
# 3022    True
# 3023    True
# 3024    True
# 3025    True
# 3026    True
# 3027    True
# 3028    True
# 3029    True
# 3030    True
# 3031    True
# 3032    True
# 3033    True
# 3034    True
# 3035    True
# 3036    True
# 3037    True
# 3038    True
# 3039    True
# 3040    True
# 3041    True
# 3042    True
# 3043    True
# 3044    True
# Name: Population, dtype: bool

# %%
lostsuperreal = lostsuper[lostsuper.Population.notnull()]
lostsuperreal
# Out:
#       Postcode                 Suburb State  LS_Accounts     LS_Value  \
# 95        2000             Barangaroo   NSW         1867  35055841.48
# 99        2006       Camperdown (NSW)   NSW           18    407013.68
# 100       2007                 Ultimo   NSW          229   3689907.02
# 101       2008            Chippendale   NSW          364   7076919.35
# 102       2009                Pyrmont   NSW          576  11785930.38
# 103       2010           Darlinghurst   NSW         1743  34721863.97
# 104       2011          Elizabeth Bay   NSW         1162  22996709.20
# 108       2015             Alexandria   NSW          469   8667863.07
# 109       2016                Redfern   NSW          625  11445542.24
# 110       2017         Waterloo (NSW)   NSW          570   9440705.20
# 111       2018              Eastlakes   NSW          473   8258806.47
# 112       2019            Banksmeadow   NSW          309   7138821.39
# ...

# %%
lostsuperreal.describe()
# Out:
#           Postcode  LS_Accounts      LS_Value    Population  \
# count  2492.000000  2492.000000  2.492000e+03    2492.00000
# mean   4105.762039   220.047352  4.299685e+06    8608.33427
# std    1501.236889   301.984859  5.837094e+06   11468.34475
# min     800.000000     1.000000  3.051000e+01       0.00000
# 25%    2844.750000    19.000000  3.355736e+05     877.75000
# 50%    3885.500000    86.500000  1.632610e+06    3627.00000
# 75%    5171.250000   315.000000  6.413329e+06   12733.25000
# max    7470.000000  2903.000000  4.925634e+07  102245.00000
#
#        LS_Accounts_Per_Person  LS_Value_Per_Person  Tax_Population  \
# count             2489.000000          2489.000000     2191.000000
# mean                 0.028534           537.938887     5814.040621
# std                  0.071572          1355.703831     7046.849297
# min                  0.000000             0.120000      201.000000
# 25%                  0.020000           322.130000      780.000000
# ...

# %%
lostsuperreal.dtypes
# Out:
# Postcode                    int64
# Suburb                     object
# State                      object
# LS_Accounts                 int64
# LS_Value                  float64
# Population                float64
# LS_Accounts_Per_Person    float64
# LS_Value_Per_Person       float64
# Tax_Population            float64
# Tax_Median_Income         float64
# Tax_Mean_Income           float64
# dtype: object

# %% [markdown]
# only suburb and state should be objects, the rest are numbers and I need to make them numbers

# %%
lostsuperreal.LS_Value.isnull().value_counts()
# Out:
# False    2492
# Name: LS_Value, dtype: int64

# %%
lostsuperreal.dtypes
# Out:
# Postcode                    int64
# Suburb                     object
# State                      object
# LS_Accounts                 int64
# LS_Value                  float64
# Population                float64
# LS_Accounts_Per_Person    float64
# LS_Value_Per_Person       float64
# Tax_Population            float64
# Tax_Median_Income         float64
# Tax_Mean_Income           float64
# dtype: object

# %% [markdown]
# I dont understand why LS_Value is showing as an object in the dtypes when it shows as an int64 in the line above

# %%
lostsuperreal.Population.isnull().value_counts()
# Out:
# False    2492
# Name: Population, dtype: int64

# %% [markdown]
# again, population says its int64 but object in the dtypes

# %%
lostsuperreal2 = lostsuperreal.convert_objects(convert_numeric=True)
# Out:
# /Users/chrislumby/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
lostsuperreal2
# Out:
#       Postcode                 Suburb State  LS_Accounts     LS_Value  \
# 95        2000             Barangaroo   NSW         1867  35055841.48
# 99        2006       Camperdown (NSW)   NSW           18    407013.68
# 100       2007                 Ultimo   NSW          229   3689907.02
# 101       2008            Chippendale   NSW          364   7076919.35
# 102       2009                Pyrmont   NSW          576  11785930.38
# 103       2010           Darlinghurst   NSW         1743  34721863.97
# 104       2011          Elizabeth Bay   NSW         1162  22996709.20
# 108       2015             Alexandria   NSW          469   8667863.07
# 109       2016                Redfern   NSW          625  11445542.24
# 110       2017         Waterloo (NSW)   NSW          570   9440705.20
# 111       2018              Eastlakes   NSW          473   8258806.47
# 112       2019            Banksmeadow   NSW          309   7138821.39
# ...

# %% [markdown]
# This has converted the two population columns to NaN - but not in every instance. Not sure why.....

# %%
lostsuperreal2.dtypes
# Out:
# Postcode                    int64
# Suburb                     object
# State                      object
# LS_Accounts                 int64
# LS_Value                  float64
# Population                float64
# LS_Accounts_Per_Person    float64
# LS_Value_Per_Person       float64
# Tax_Population            float64
# Tax_Median_Income         float64
# Tax_Mean_Income           float64
# dtype: object

# %% [markdown]
# I'm going to convert all the data in the CSV to remove $ and commas

# %% [markdown]
# YES!!! it worked. but i could only fix it in the source file rather than in python......

# %% [markdown]
# now working out how much lost super has been taken out due to being attached to a postcode that doesnt exist.

# %%
lostsuper.LS_Value(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-60408fa1911b> in <module>()
# ----> 1 lostsuper.LS_Value(sum)
#
# TypeError: 'Series' object is not callable

# %%
lostsuper.sum.LS_Value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-42ecb46cf6c0> in <module>()
# ----> 1 lostsuper.sum.LS_Value()
#
# AttributeError: 'function' object has no attribute 'LS_Value'

# %%
lostsuper.LS_Value.sum()
# Out:
# 10792407265.650026

# %%
lostsuperreal2.LS_Value.sum()
# Out:
# 10714814015.39002

# %%
import math

# %%
lostsuper.LS_Value.sum() - lostsuperreal2.LS_Value.sum()
# Out:
# 77593250.26000595

# %%
(lostsuper.LS_Value.sum() - lostsuperreal2.LS_Value.sum())/(lostsuper.LS_Value.sum())*100
# Out:
# 0.718961473099417

# %% [markdown]
# So less than 1% of value removed due to postcode errors. This is a good result. And data remains credible

# %% [markdown]
# Now trying to work out LS Value Per Person by state and then visualise

# %%
lostsuperreal2.LS_Value_Per_Person.sum()
# Out:
# 1338929.889999997

# %%
lostsuperNSW = lostsuperreal2.State('NSW')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-04b83e1aa0ab> in <module>()
# ----> 1 lostsuperNSW = lostsuperreal2.State('NSW')
#
# TypeError: 'Series' object is not callable

# %%
lostsuperreal2.groupby('State').LS_Value_Per_Person.mean()
# Out:
# State
# ACT    712.888800
# NSW    518.247347
# NT     805.732414
# QLD    554.629526
# SA     443.209553
# TAS    365.951759
# VIC    475.869396
# WA     788.720795
# Name: LS_Value_Per_Person, dtype: float64

# %%
lostsuperreal2.groupby('State').Tax_Median_Income.mean()
# Out:
# State
# ACT    56106.708333
# NSW    40962.891798
# NT     50598.000000
# QLD    40680.060367
# SA     39860.769811
# TAS    37958.191489
# VIC    38665.987762
# WA     48159.162162
# Name: Tax_Median_Income, dtype: float64

# %%
import seaborn
# %matplotlib inline

# %%
scatter.plot(lostsuperreal2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-fd5136e92b7f> in <module>()
# ----> 1 scatter.plot(lostsuperreal2)
#
# NameError: name 'scatter' is not defined

# %%
lostsuperreal2.LS_Value_Per_Person.sort_values().plot()

# %%
lostsuperreal2.State.unique()
# Out:
# array(['NSW', 'ACT', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA'], dtype=object)

# %%
seaborn.violinplot(x='State', y='LS_Value_Per_Person', data=lostsuperreal2)

# %% [markdown]
# The data is more consistent than I thought it would be. Having said that, the higher paid and transient workforces in WA and NT have the highest Lost Super per population which isn't suprising. There are clearly some high outlier postcodes that need more data attributes to uncover why their lost super is so high.

# %%
seaborn.violinplot(x='State', y='LS_Value_Per_Person'<50000, data=lostsuperreal2)

# %% [markdown]
# The above was trying to cut the outliers out to see the definition in chart but didnt work. I've also been trying the swarmplot but it keeps timing out then the whole thing crashes.

# %%
X = lostsuperreal2.Tax_Median_Income

# %%
y = lostsuperreal2.LS_Value_Per_Person

# %%
import matplotlib
matplotlib.pyplot.scatter(X,y)

# %%
X = lostsuperreal2.Tax_Mean_Income

# %%
matplotlib.pyplot.scatter(X,y)

# %% [markdown]
# If have time then do the scatter and colour by states using numpy

# %% [markdown]
# The tax office income data doesnt recognise all postcodes so I need to remove the nulls

# %%
lostsuperreal3 = lostsuperreal2[lostsuperreal2.Tax_Population.notnull()]
lostsuperreal3
# Out:
#       Postcode                 Suburb State  LS_Accounts     LS_Value  \
# 95        2000             Barangaroo   NSW         1867  35055841.48
# 100       2007                 Ultimo   NSW          229   3689907.02
# 101       2008            Chippendale   NSW          364   7076919.35
# 102       2009                Pyrmont   NSW          576  11785930.38
# 103       2010           Darlinghurst   NSW         1743  34721863.97
# 104       2011          Elizabeth Bay   NSW         1162  22996709.20
# 108       2015             Alexandria   NSW          469   8667863.07
# 109       2016                Redfern   NSW          625  11445542.24
# 110       2017         Waterloo (NSW)   NSW          570   9440705.20
# 111       2018              Eastlakes   NSW          473   8258806.47
# 112       2019            Banksmeadow   NSW          309   7138821.39
# 113       2020                 Mascot   NSW          429   7142263.42
# ...

# %%
lostsuperreal3.dtypes
# Out:
# Postcode                    int64
# Suburb                     object
# State                      object
# LS_Accounts                 int64
# LS_Value                  float64
# Population                float64
# LS_Accounts_Per_Person    float64
# LS_Value_Per_Person       float64
# Tax_Population            float64
# Tax_Median_Income         float64
# Tax_Mean_Income           float64
# dtype: object

# %%
(lostsuper.LS_Value.sum() - lostsuperreal3.LS_Value.sum())/(lostsuper.LS_Value.sum())*100
# Out:
# 1.1656517267506223

# %%
lostsuperreal3.LS_Value.sum()
# Out:
# 10666605384.000017

# %% [markdown]
# After getting rid of tax office postcode data gaps, we are only 1% in value less than original data set so all good!!!! Time to try a regression.....

# %%
lostsuperreal3.describe()
# Out:
#           Postcode  LS_Accounts      LS_Value     Population  \
# count  2191.000000  2191.000000  2.191000e+03    2191.000000
# mean   4032.735281   249.052031  4.868373e+06    9733.278412
# std    1486.339178   311.008476  6.004698e+06   11793.358236
# min     800.000000     2.000000  1.502689e+04     120.000000
# 25%    2777.500000    33.000000  6.173147e+05    1428.000000
# 50%    3814.000000   124.000000  2.441898e+06    5198.000000
# 75%    5093.500000   359.000000  7.211964e+06   14080.000000
# max    7470.000000  2903.000000  4.925634e+07  102245.000000
#
#        LS_Accounts_Per_Person  LS_Value_Per_Person  Tax_Population  \
# count             2191.000000          2191.000000     2191.000000
# mean                 0.025915           495.150037     5814.040621
# std                  0.011427           238.850896     7046.849297
# min                  0.000000            40.290000      201.000000
# 25%                  0.020000           344.030000      780.000000
# ...

# %%
lostsuperreal3.corr()
# Out:
#                         Postcode  LS_Accounts  LS_Value  Population  \
# Postcode                1.000000    -0.156409 -0.196503   -0.187897
# LS_Accounts            -0.156409     1.000000  0.981185    0.933653
# LS_Value               -0.196503     0.981185  1.000000    0.926197
# Population             -0.187897     0.933653  0.926197    1.000000
# LS_Accounts_Per_Person  0.099732     0.182324  0.166564   -0.014051
# LS_Value_Per_Person    -0.025091     0.187765  0.231495    0.017382
# Tax_Population         -0.181500     0.952939  0.956339    0.983152
# Tax_Median_Income       0.045299     0.311034  0.354925    0.213081
# Tax_Mean_Income        -0.033752     0.254451  0.323514    0.154669
#
#                         LS_Accounts_Per_Person  LS_Value_Per_Person  \
# Postcode                              0.099732            -0.025091
# LS_Accounts                           0.182324             0.187765
# LS_Value                              0.166564             0.231495
# ...

# %%
X = lostsuperreal3[['Tax_Median_Income']]

# %%
y = lostsuperreal3.LS_Value_Per_Person

# %%
import sklearn.linear_model
clf = sklearn.linear_model.LinearRegression()
clf.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.predict([[10000], [80000], [200000]])
# Out:
# array([  112.66714384,   971.64000069,  2444.16489816])

# %%
clf.coef_
# Out:
# array([ 0.01227104])

# %%
clf.intercept_
# Out:
# -10.043264286859937

# %%
lostsuperreal3.LS_Value_Per_Person.sort_values().head()
# Out:
# 2273    40.29
# 999     44.33
# 1522    44.97
# 2538    49.98
# 2106    53.67
# Name: LS_Value_Per_Person, dtype: float64

# %%
seaborn.violinplot(x='State', y='LS_Value_Per_Person', data=lostsuperreal3)

# %%
seaborn.swarmplot(x='State', y='LS_Value_Per_Person', data=lostsuperreal3)

# %% [markdown]
# This is far more interesting. Removing the postcodes that the ATO doesn't recognise removes the extreme outliers and provides a better picture of whats actually going on

# %%
matplotlib.pyplot.scatter(X,y)

# %% [markdown]
# This chart looks the same as previous because it must have already removed the ATO non postcodes by default. Happy with progress!!!!!
